# %% [markdown]
# #Импорты

# %%
# Import torch
import torch
from torch import nn
import os
import zipfile
from pathlib import Path
import requests

# Import torchvision
import torchvision
from torchvision import datasets, transforms
from torchvision import datasets
from torchvision.transforms import ToTensor

# Continue with regular imports
import matplotlib.pyplot as plt
# !pip install -q torchinfo
from torchinfo import summary
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
from typing import Dict, List, Tuple


! pip install -q kaggle

# Note: this notebook requires torch >= 1.10.0
torch.__version__
# Out:
# '2.3.0+cu121'

# %%
# Setup device-agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# # Создаем каталоги

# %%
# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "sports-classification"


# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)
    ! kaggle datasets download -d gpiosenka/sports-classification
    # Download data

    # Unzip data
    with zipfile.ZipFile("sports-classification.zip", "r") as zip_ref:
        print("Unzipping data...")
        zip_ref.extractall(image_path)
# Out:
# Did not find data/sports-classification directory, creating one...
# Dataset URL: https://www.kaggle.com/datasets/gpiosenka/sports-classification
# License(s): CC0-1.0
# Downloading sports-classification.zip to /content
#  98% 415M/424M [00:05<00:00, 106MB/s]
# 100% 424M/424M [00:05<00:00, 87.1MB/s]
# Unzipping data...

# %%
def walk_through_dir(dir_path):

  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(image_path)
# Out:
# There are 3 directories and 2 images in 'data/sports-classification'.
# There are 100 directories and 0 images in 'data/sports-classification/valid'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/rollerblade racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/jai alai'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/boxing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/billiards'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/sidecar racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/nascar racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/mushing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/shuffleboard'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/swimming'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/hang gliding'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bobsled'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/high jump'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/lacrosse'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/judo'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/snowmobile racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/cheerleading'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/arm wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/parallel bar'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/motorcycle racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/basketball'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/pole dancing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/air hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/sumo wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/wheelchair racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/rugby'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/polo'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/uneven bars'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/ultimate'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/speed skating'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/croquet'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/water cycling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/shot put'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/figure skating women'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/track bicycle'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/ice yachting'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/surfing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bull riding'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/pommel horse'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/fly fishing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/curling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/figure skating men'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/hydroplane racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/wingsuit flying'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/tug of war'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/disc golf'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/canoe slamon'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/table tennis'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/weightlifting'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/axe throwing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/pole vault'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/figure skating pairs'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/javelin'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/volleyball'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/tennis'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/trapeze'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/steer wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bike polo'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/log rolling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/water polo'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/luge'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/gaga'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/harness racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/baseball'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/jousting'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/ampute football'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/snow boarding'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/golf'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/rock climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/cricket'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/archery'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/rings'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/wheelchair basketball'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/skydiving'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/horse jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/roller derby'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/chuckwagon racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/olympic wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bungee jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/hurdles'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/field hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/barell racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/fencing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bowling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/giant slalom'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/sailboat racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/frisbee'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/ski jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/horse racing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/ice climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/horseshoe pitching'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/football'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/bmx'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/pole climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/sky surfing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/rowing'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/baton twirling'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/hammer throw'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/balance beam'.
# There are 0 directories and 5 images in 'data/sports-classification/valid/formula 1 racing'.
# There are 100 directories and 0 images in 'data/sports-classification/train'.
# There are 0 directories and 159 images in 'data/sports-classification/train/rollerblade racing'.
# There are 0 directories and 132 images in 'data/sports-classification/train/jai alai'.
# There are 0 directories and 116 images in 'data/sports-classification/train/boxing'.
# There are 0 directories and 145 images in 'data/sports-classification/train/billiards'.
# There are 0 directories and 133 images in 'data/sports-classification/train/sidecar racing'.
# There are 0 directories and 189 images in 'data/sports-classification/train/nascar racing'.
# There are 0 directories and 111 images in 'data/sports-classification/train/mushing'.
# There are 0 directories and 130 images in 'data/sports-classification/train/shuffleboard'.
# There are 0 directories and 157 images in 'data/sports-classification/train/swimming'.
# There are 0 directories and 121 images in 'data/sports-classification/train/hang gliding'.
# There are 0 directories and 138 images in 'data/sports-classification/train/bobsled'.
# There are 0 directories and 159 images in 'data/sports-classification/train/high jump'.
# There are 0 directories and 151 images in 'data/sports-classification/train/lacrosse'.
# There are 0 directories and 150 images in 'data/sports-classification/train/judo'.
# There are 0 directories and 147 images in 'data/sports-classification/train/snowmobile racing'.
# There are 0 directories and 131 images in 'data/sports-classification/train/cheerleading'.
# There are 0 directories and 99 images in 'data/sports-classification/train/arm wrestling'.
# There are 0 directories and 131 images in 'data/sports-classification/train/parallel bar'.
# There are 0 directories and 132 images in 'data/sports-classification/train/motorcycle racing'.
# There are 0 directories and 169 images in 'data/sports-classification/train/basketball'.
# There are 0 directories and 112 images in 'data/sports-classification/train/pole dancing'.
# There are 0 directories and 112 images in 'data/sports-classification/train/air hockey'.
# There are 0 directories and 133 images in 'data/sports-classification/train/sumo wrestling'.
# There are 0 directories and 119 images in 'data/sports-classification/train/wheelchair racing'.
# There are 0 directories and 166 images in 'data/sports-classification/train/rugby'.
# There are 0 directories and 157 images in 'data/sports-classification/train/polo'.
# There are 0 directories and 156 images in 'data/sports-classification/train/uneven bars'.
# There are 0 directories and 97 images in 'data/sports-classification/train/ultimate'.
# There are 0 directories and 136 images in 'data/sports-classification/train/speed skating'.
# There are 0 directories and 134 images in 'data/sports-classification/train/croquet'.
# There are 0 directories and 103 images in 'data/sports-classification/train/water cycling'.
# There are 0 directories and 149 images in 'data/sports-classification/train/shot put'.
# There are 0 directories and 157 images in 'data/sports-classification/train/figure skating women'.
# There are 0 directories and 135 images in 'data/sports-classification/train/track bicycle'.
# There are 0 directories and 112 images in 'data/sports-classification/train/ice yachting'.
# There are 0 directories and 142 images in 'data/sports-classification/train/surfing'.
# There are 0 directories and 149 images in 'data/sports-classification/train/bull riding'.
# There are 0 directories and 120 images in 'data/sports-classification/train/pommel horse'.
# There are 0 directories and 134 images in 'data/sports-classification/train/fly fishing'.
# There are 0 directories and 141 images in 'data/sports-classification/train/curling'.
# There are 0 directories and 128 images in 'data/sports-classification/train/figure skating men'.
# There are 0 directories and 108 images in 'data/sports-classification/train/hydroplane racing'.
# There are 0 directories and 98 images in 'data/sports-classification/train/wingsuit flying'.
# There are 0 directories and 128 images in 'data/sports-classification/train/tug of war'.
# There are 0 directories and 123 images in 'data/sports-classification/train/disc golf'.
# There are 0 directories and 164 images in 'data/sports-classification/train/canoe slamon'.
# There are 0 directories and 141 images in 'data/sports-classification/train/table tennis'.
# There are 0 directories and 134 images in 'data/sports-classification/train/weightlifting'.
# There are 0 directories and 113 images in 'data/sports-classification/train/axe throwing'.
# There are 0 directories and 138 images in 'data/sports-classification/train/pole vault'.
# There are 0 directories and 151 images in 'data/sports-classification/train/figure skating pairs'.
# There are 0 directories and 136 images in 'data/sports-classification/train/javelin'.
# There are 0 directories and 142 images in 'data/sports-classification/train/volleyball'.
# There are 0 directories and 131 images in 'data/sports-classification/train/tennis'.
# There are 0 directories and 125 images in 'data/sports-classification/train/trapeze'.
# There are 0 directories and 122 images in 'data/sports-classification/train/steer wrestling'.
# There are 0 directories and 110 images in 'data/sports-classification/train/bike polo'.
# There are 0 directories and 128 images in 'data/sports-classification/train/log rolling'.
# There are 0 directories and 130 images in 'data/sports-classification/train/water polo'.
# There are 0 directories and 127 images in 'data/sports-classification/train/luge'.
# There are 0 directories and 118 images in 'data/sports-classification/train/gaga'.
# There are 0 directories and 147 images in 'data/sports-classification/train/harness racing'.
# There are 0 directories and 174 images in 'data/sports-classification/train/baseball'.
# There are 0 directories and 118 images in 'data/sports-classification/train/jousting'.
# There are 0 directories and 112 images in 'data/sports-classification/train/ampute football'.
# There are 0 directories and 117 images in 'data/sports-classification/train/snow boarding'.
# There are 0 directories and 157 images in 'data/sports-classification/train/golf'.
# There are 0 directories and 141 images in 'data/sports-classification/train/rock climbing'.
# There are 0 directories and 129 images in 'data/sports-classification/train/cricket'.
# There are 0 directories and 132 images in 'data/sports-classification/train/archery'.
# There are 0 directories and 157 images in 'data/sports-classification/train/rings'.
# There are 0 directories and 106 images in 'data/sports-classification/train/wheelchair basketball'.
# There are 0 directories and 148 images in 'data/sports-classification/train/skydiving'.
# There are 0 directories and 134 images in 'data/sports-classification/train/horse jumping'.
# There are 0 directories and 163 images in 'data/sports-classification/train/roller derby'.
# There are 0 directories and 120 images in 'data/sports-classification/train/chuckwagon racing'.
# There are 0 directories and 167 images in 'data/sports-classification/train/olympic wrestling'.
# There are 0 directories and 125 images in 'data/sports-classification/train/bungee jumping'.
# There are 0 directories and 136 images in 'data/sports-classification/train/hurdles'.
# There are 0 directories and 157 images in 'data/sports-classification/train/field hockey'.
# There are 0 directories and 172 images in 'data/sports-classification/train/hockey'.
# There are 0 directories and 123 images in 'data/sports-classification/train/barell racing'.
# There are 0 directories and 135 images in 'data/sports-classification/train/fencing'.
# There are 0 directories and 120 images in 'data/sports-classification/train/bowling'.
# There are 0 directories and 150 images in 'data/sports-classification/train/giant slalom'.
# There are 0 directories and 144 images in 'data/sports-classification/train/sailboat racing'.
# There are 0 directories and 131 images in 'data/sports-classification/train/frisbee'.
# There are 0 directories and 130 images in 'data/sports-classification/train/ski jumping'.
# There are 0 directories and 139 images in 'data/sports-classification/train/horse racing'.
# There are 0 directories and 130 images in 'data/sports-classification/train/ice climbing'.
# There are 0 directories and 102 images in 'data/sports-classification/train/horseshoe pitching'.
# There are 0 directories and 191 images in 'data/sports-classification/train/football'.
# There are 0 directories and 140 images in 'data/sports-classification/train/bmx'.
# There are 0 directories and 118 images in 'data/sports-classification/train/pole climbing'.
# There are 0 directories and 59 images in 'data/sports-classification/train/sky surfing'.
# There are 0 directories and 143 images in 'data/sports-classification/train/rowing'.
# There are 0 directories and 108 images in 'data/sports-classification/train/baton twirling'.
# There are 0 directories and 122 images in 'data/sports-classification/train/hammer throw'.
# There are 0 directories and 147 images in 'data/sports-classification/train/balance beam'.
# There are 0 directories and 190 images in 'data/sports-classification/train/formula 1 racing'.
# There are 100 directories and 0 images in 'data/sports-classification/test'.
# There are 0 directories and 5 images in 'data/sports-classification/test/rollerblade racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/jai alai'.
# There are 0 directories and 5 images in 'data/sports-classification/test/boxing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/billiards'.
# There are 0 directories and 5 images in 'data/sports-classification/test/sidecar racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/nascar racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/mushing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/shuffleboard'.
# There are 0 directories and 5 images in 'data/sports-classification/test/swimming'.
# There are 0 directories and 5 images in 'data/sports-classification/test/hang gliding'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bobsled'.
# There are 0 directories and 5 images in 'data/sports-classification/test/high jump'.
# There are 0 directories and 5 images in 'data/sports-classification/test/lacrosse'.
# There are 0 directories and 5 images in 'data/sports-classification/test/judo'.
# There are 0 directories and 5 images in 'data/sports-classification/test/snowmobile racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/cheerleading'.
# There are 0 directories and 5 images in 'data/sports-classification/test/arm wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/parallel bar'.
# There are 0 directories and 5 images in 'data/sports-classification/test/motorcycle racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/basketball'.
# There are 0 directories and 5 images in 'data/sports-classification/test/pole dancing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/air hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/test/sumo wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/wheelchair racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/rugby'.
# There are 0 directories and 5 images in 'data/sports-classification/test/polo'.
# There are 0 directories and 5 images in 'data/sports-classification/test/uneven bars'.
# There are 0 directories and 5 images in 'data/sports-classification/test/ultimate'.
# There are 0 directories and 5 images in 'data/sports-classification/test/speed skating'.
# There are 0 directories and 5 images in 'data/sports-classification/test/croquet'.
# There are 0 directories and 5 images in 'data/sports-classification/test/water cycling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/shot put'.
# There are 0 directories and 5 images in 'data/sports-classification/test/figure skating women'.
# There are 0 directories and 5 images in 'data/sports-classification/test/track bicycle'.
# There are 0 directories and 5 images in 'data/sports-classification/test/ice yachting'.
# There are 0 directories and 5 images in 'data/sports-classification/test/surfing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bull riding'.
# There are 0 directories and 5 images in 'data/sports-classification/test/pommel horse'.
# There are 0 directories and 5 images in 'data/sports-classification/test/fly fishing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/curling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/figure skating men'.
# There are 0 directories and 5 images in 'data/sports-classification/test/hydroplane racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/wingsuit flying'.
# There are 0 directories and 5 images in 'data/sports-classification/test/tug of war'.
# There are 0 directories and 5 images in 'data/sports-classification/test/disc golf'.
# There are 0 directories and 5 images in 'data/sports-classification/test/canoe slamon'.
# There are 0 directories and 5 images in 'data/sports-classification/test/table tennis'.
# There are 0 directories and 5 images in 'data/sports-classification/test/weightlifting'.
# There are 0 directories and 5 images in 'data/sports-classification/test/axe throwing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/pole vault'.
# There are 0 directories and 5 images in 'data/sports-classification/test/figure skating pairs'.
# There are 0 directories and 5 images in 'data/sports-classification/test/javelin'.
# There are 0 directories and 5 images in 'data/sports-classification/test/volleyball'.
# There are 0 directories and 5 images in 'data/sports-classification/test/tennis'.
# There are 0 directories and 5 images in 'data/sports-classification/test/trapeze'.
# There are 0 directories and 5 images in 'data/sports-classification/test/steer wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bike polo'.
# There are 0 directories and 5 images in 'data/sports-classification/test/log rolling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/water polo'.
# There are 0 directories and 5 images in 'data/sports-classification/test/luge'.
# There are 0 directories and 5 images in 'data/sports-classification/test/gaga'.
# There are 0 directories and 5 images in 'data/sports-classification/test/harness racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/baseball'.
# There are 0 directories and 5 images in 'data/sports-classification/test/jousting'.
# There are 0 directories and 5 images in 'data/sports-classification/test/ampute football'.
# There are 0 directories and 5 images in 'data/sports-classification/test/snow boarding'.
# There are 0 directories and 5 images in 'data/sports-classification/test/golf'.
# There are 0 directories and 5 images in 'data/sports-classification/test/rock climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/cricket'.
# There are 0 directories and 5 images in 'data/sports-classification/test/archery'.
# There are 0 directories and 5 images in 'data/sports-classification/test/rings'.
# There are 0 directories and 5 images in 'data/sports-classification/test/wheelchair basketball'.
# There are 0 directories and 5 images in 'data/sports-classification/test/skydiving'.
# There are 0 directories and 5 images in 'data/sports-classification/test/horse jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/test/roller derby'.
# There are 0 directories and 5 images in 'data/sports-classification/test/chuckwagon racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/olympic wrestling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bungee jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/test/hurdles'.
# There are 0 directories and 5 images in 'data/sports-classification/test/field hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/test/hockey'.
# There are 0 directories and 5 images in 'data/sports-classification/test/barell racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/fencing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bowling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/giant slalom'.
# There are 0 directories and 5 images in 'data/sports-classification/test/sailboat racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/frisbee'.
# There are 0 directories and 5 images in 'data/sports-classification/test/ski jumping'.
# There are 0 directories and 5 images in 'data/sports-classification/test/horse racing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/ice climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/horseshoe pitching'.
# There are 0 directories and 5 images in 'data/sports-classification/test/football'.
# There are 0 directories and 5 images in 'data/sports-classification/test/bmx'.
# There are 0 directories and 5 images in 'data/sports-classification/test/pole climbing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/sky surfing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/rowing'.
# There are 0 directories and 5 images in 'data/sports-classification/test/baton twirling'.
# There are 0 directories and 5 images in 'data/sports-classification/test/hammer throw'.
# There are 0 directories and 5 images in 'data/sports-classification/test/balance beam'.
# There are 0 directories and 5 images in 'data/sports-classification/test/formula 1 racing'.

# %%
# Setup train and testing paths
train_dir = image_path / "train"
test_dir = image_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('data/sports-classification/train'),
#  PosixPath('data/sports-classification/test'))

# %% [markdown]
# #Функции

# %%
NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str,
    test_dir: str,
    transform: transforms.Compose,
    batch_size: int,
    num_workers: int=NUM_WORKERS
):
  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Tuple[float, float]:

    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device) -> Tuple[float, float]:

     # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device) -> Dict[str, List]:

    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Make sure model on target device
    model.to(device)

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                          dataloader=train_dataloader,
                                          loss_fn=loss_fn,
                                          optimizer=optimizer,
                                          device=device)
        test_loss, test_acc = test_step(model=model,
          dataloader=test_dataloader,
          loss_fn=loss_fn,
          device=device)

        # Print out what's happening
        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    # Return the filled results at the end of the epochs
    return results

# %%
def plot_loss_curves(results):

    loss = results["train_loss"]
    test_loss = results["test_loss"]

    accuracy = results["train_acc"]
    test_accuracy = results["test_acc"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label="train_accuracy")
    plt.plot(epochs, test_accuracy, label="test_accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

# %% [markdown]
# #Трансформ

# %%
# Create a transforms pipeline manually (required for torchvision < 0.13)

manual_transforms = transforms.Compose([
    transforms.Resize((224, 224)), # 1. Reshape all images to 224x224 (though some models may require different sizes)
    transforms.ToTensor(), # 2. Turn image values to between 0 & 1
    transforms.Normalize(mean=[0.485, 0.456, 0.406], # 3. A mean of [0.485, 0.456, 0.406] (across each colour channel)
                         std=[0.229, 0.224, 0.225]) # 4. A standard deviation of [0.229, 0.224, 0.225] (across each colour channel),
])

# %%
# Create training and testing DataLoaders as well as get a list of class names
train_dataloader, test_dataloader, class_names = create_dataloaders(train_dir=train_dir,
                                                                               test_dir=test_dir,
                                                                               transform=manual_transforms, # resize, convert images to between 0 & 1 and normalize them
                                                                               batch_size=32) # set mini-batch size to 32

train_dataloader, test_dataloader, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7d90ec3b7df0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7d90ec3b7760>,
#  ['air hockey',
#   'ampute football',
#   'archery',
#   'arm wrestling',
#   'axe throwing',
#   'balance beam',
#   'barell racing',
#   'baseball',
#   'basketball',
#   'baton twirling',
#   'bike polo',
#   'billiards',
#   'bmx',
#   'bobsled',
#   'bowling',
#   'boxing',
#   'bull riding',
#   'bungee jumping',
#   'canoe slamon',
#   'cheerleading',
#   'chuckwagon racing',
#   'cricket',
#   'croquet',
#   'curling',
#   'disc golf',
#   'fencing',
#   'field hockey',
#   'figure skating men',
#   'figure skating pairs',
#   'figure skating women',
#   'fly fishing',
#   'football',
#   'formula 1 racing',
#   'frisbee',
#   'gaga',
#   'giant slalom',
#   'golf',
#   'hammer throw',
#   'hang gliding',
#   'harness racing',
#   'high jump',
#   'hockey',
#   'horse jumping',
#   'horse racing',
#   'horseshoe pitching',
#   'hurdles',
#   'hydroplane racing',
#   'ice climbing',
#   'ice yachting',
#   'jai alai',
#   'javelin',
#   'jousting',
#   'judo',
#   'lacrosse',
#   'log rolling',
#   'luge',
#   'motorcycle racing',
#   'mushing',
#   'nascar racing',
#   'olympic wrestling',
#   'parallel bar',
#   'pole climbing',
#   'pole dancing',
#   'pole vault',
#   'polo',
#   'pommel horse',
#   'rings',
#   'rock climbing',
#   'roller derby',
#   'rollerblade racing',
#   'rowing',
#   'rugby',
#   'sailboat racing',
#   'shot put',
#   'shuffleboard',
#   'sidecar racing',
#   'ski jumping',
#   'sky surfing',
#   'skydiving',
#   'snow boarding',
#   'snowmobile racing',
#   'speed skating',
#   'steer wrestling',
#   'sumo wrestling',
#   'surfing',
#   'swimming',
#   'table tennis',
#   'tennis',
#   'track bicycle',
#   'trapeze',
#   'tug of war',
#   'ultimate',
#   'uneven bars',
#   'volleyball',
#   'water cycling',
#   'water polo',
#   'weightlifting',
#   'wheelchair basketball',
#   'wheelchair racing',
#   'wingsuit flying'])

# %% [markdown]
# #Модель

# %%
model = torchvision.models.efficientnet_b3(pretrained=True).to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B3_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100%|██████████| 47.2M/47.2M [00:02<00:00, 20.0MB/s]

# %%
# Print a summary using torchinfo (uncomment for actual output)
summary(model=model,
        input_size=(32, 3, 224, 224), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 1000]           --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1536, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 40, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 40, 112, 112]   1,080                True
# │    │    └─BatchNorm2d (1)                                  [32, 40, 112, 112]   [32, 40, 112, 112]   80                   True
# │    │    └─SiLU (2)                                         [32, 40, 112, 112]   [32, 40, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 40, 112, 112]   [32, 24, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 40, 112, 112]   [32, 24, 112, 112]   2,298                True
# │    │    └─MBConv (1)                                       [32, 24, 112, 112]   [32, 24, 112, 112]   1,206                True
# │    └─Sequential (2)                                        [32, 24, 112, 112]   [32, 32, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 112, 112]   [32, 32, 56, 56]     11,878               True
# │    │    └─MBConv (1)                                       [32, 32, 56, 56]     [32, 32, 56, 56]     18,120               True
# │    │    └─MBConv (2)                                       [32, 32, 56, 56]     [32, 32, 56, 56]     18,120               True
# │    └─Sequential (3)                                        [32, 32, 56, 56]     [32, 48, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 32, 56, 56]     [32, 48, 28, 28]     24,296               True
# │    │    └─MBConv (1)                                       [32, 48, 28, 28]     [32, 48, 28, 28]     43,308               True
# │    │    └─MBConv (2)                                       [32, 48, 28, 28]     [32, 48, 28, 28]     43,308               True
# │    └─Sequential (4)                                        [32, 48, 28, 28]     [32, 96, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 48, 28, 28]     [32, 96, 14, 14]     52,620               True
# │    │    └─MBConv (1)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (2)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (3)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (4)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    └─Sequential (5)                                        [32, 96, 14, 14]     [32, 136, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 96, 14, 14]     [32, 136, 14, 14]    178,856              True
# │    │    └─MBConv (1)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (2)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (3)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (4)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    └─Sequential (6)                                        [32, 136, 14, 14]    [32, 232, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 136, 14, 14]    [32, 232, 7, 7]      380,754              True
# │    │    └─MBConv (1)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (2)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (3)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (4)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (5)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    └─Sequential (7)                                        [32, 232, 7, 7]      [32, 384, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 232, 7, 7]      [32, 384, 7, 7]      1,039,258            True
# │    │    └─MBConv (1)                                       [32, 384, 7, 7]      [32, 384, 7, 7]      2,244,960            True
# │    └─Conv2dNormActivation (8)                              [32, 384, 7, 7]      [32, 1536, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 384, 7, 7]      [32, 1536, 7, 7]     589,824              True
# │    │    └─BatchNorm2d (1)                                  [32, 1536, 7, 7]     [32, 1536, 7, 7]     3,072                True
# │    │    └─SiLU (2)                                         [32, 1536, 7, 7]     [32, 1536, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1536, 7, 7]     [32, 1536, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1536]           [32, 1000]           --                   True
# │    └─Dropout (0)                                           [32, 1536]           [32, 1536]           --                   --
# │    └─Linear (1)                                            [32, 1536]           [32, 1000]           1,537,000            True
# ============================================================================================================================================
# Total params: 12,233,232
# Trainable params: 12,233,232
# Non-trainable params: 0
# Total mult-adds (G): 30.81
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 6654.32
# Params size (MB): 48.93
# Estimated Total Size (MB): 6722.52
# ============================================================================================================================================

# %%
# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Get the length of class_names (one output unit for each class)
output_shape = len(class_names)

# Recreate the classifier layer and seed it to the target device
model.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2, inplace=True),
    torch.nn.Linear(in_features=1536,
                    out_features=output_shape, # same number of output units as our number of classes
                    bias=True)).to(device)

# %%
# # Do a summary *after* freezing the features and changing the output classifier layer (uncomment for actual output)
summary(model,
        input_size=(32, 3, 224, 224), # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
        verbose=0,
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 100]            --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1536, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 40, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 40, 112, 112]   1,080                True
# │    │    └─BatchNorm2d (1)                                  [32, 40, 112, 112]   [32, 40, 112, 112]   80                   True
# │    │    └─SiLU (2)                                         [32, 40, 112, 112]   [32, 40, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 40, 112, 112]   [32, 24, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 40, 112, 112]   [32, 24, 112, 112]   2,298                True
# │    │    └─MBConv (1)                                       [32, 24, 112, 112]   [32, 24, 112, 112]   1,206                True
# │    └─Sequential (2)                                        [32, 24, 112, 112]   [32, 32, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 112, 112]   [32, 32, 56, 56]     11,878               True
# │    │    └─MBConv (1)                                       [32, 32, 56, 56]     [32, 32, 56, 56]     18,120               True
# │    │    └─MBConv (2)                                       [32, 32, 56, 56]     [32, 32, 56, 56]     18,120               True
# │    └─Sequential (3)                                        [32, 32, 56, 56]     [32, 48, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 32, 56, 56]     [32, 48, 28, 28]     24,296               True
# │    │    └─MBConv (1)                                       [32, 48, 28, 28]     [32, 48, 28, 28]     43,308               True
# │    │    └─MBConv (2)                                       [32, 48, 28, 28]     [32, 48, 28, 28]     43,308               True
# │    └─Sequential (4)                                        [32, 48, 28, 28]     [32, 96, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 48, 28, 28]     [32, 96, 14, 14]     52,620               True
# │    │    └─MBConv (1)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (2)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (3)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    │    └─MBConv (4)                                       [32, 96, 14, 14]     [32, 96, 14, 14]     146,520              True
# │    └─Sequential (5)                                        [32, 96, 14, 14]     [32, 136, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 96, 14, 14]     [32, 136, 14, 14]    178,856              True
# │    │    └─MBConv (1)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (2)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (3)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    │    └─MBConv (4)                                       [32, 136, 14, 14]    [32, 136, 14, 14]    302,226              True
# │    └─Sequential (6)                                        [32, 136, 14, 14]    [32, 232, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 136, 14, 14]    [32, 232, 7, 7]      380,754              True
# │    │    └─MBConv (1)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (2)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (3)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (4)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    │    └─MBConv (5)                                       [32, 232, 7, 7]      [32, 232, 7, 7]      849,642              True
# │    └─Sequential (7)                                        [32, 232, 7, 7]      [32, 384, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 232, 7, 7]      [32, 384, 7, 7]      1,039,258            True
# │    │    └─MBConv (1)                                       [32, 384, 7, 7]      [32, 384, 7, 7]      2,244,960            True
# │    └─Conv2dNormActivation (8)                              [32, 384, 7, 7]      [32, 1536, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 384, 7, 7]      [32, 1536, 7, 7]     589,824              True
# │    │    └─BatchNorm2d (1)                                  [32, 1536, 7, 7]     [32, 1536, 7, 7]     3,072                True
# │    │    └─SiLU (2)                                         [32, 1536, 7, 7]     [32, 1536, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1536, 7, 7]     [32, 1536, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1536]           [32, 100]            --                   True
# │    └─Dropout (0)                                           [32, 1536]           [32, 1536]           --                   --
# │    └─Linear (1)                                            [32, 1536]           [32, 100]            153,700              True
# ============================================================================================================================================
# Total params: 10,849,932
# Trainable params: 10,849,932
# Non-trainable params: 0
# Total mult-adds (G): 30.77
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 6654.09
# Params size (MB): 43.40
# Estimated Total Size (MB): 6716.76
# ============================================================================================================================================

# %%
# Define loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Setup training and save the results
results = train(model=model,
                       train_dataloader=train_dataloader,
                       test_dataloader=test_dataloader,
                       optimizer=optimizer,
                       loss_fn=loss_fn,
                       epochs=5,
                       device=device)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1857 | train_acc: 0.7084 | test_loss: 0.1942 | test_acc: 0.9520
# Epoch: 2 | train_loss: 0.3230 | train_acc: 0.9055 | test_loss: 0.1158 | test_acc: 0.9648
# Epoch: 3 | train_loss: 0.1929 | train_acc: 0.9398 | test_loss: 0.1929 | test_acc: 0.9414
# Epoch: 4 | train_loss: 0.1549 | train_acc: 0.9540 | test_loss: 0.2276 | test_acc: 0.9395
# Epoch: 5 | train_loss: 0.1546 | train_acc: 0.9521 | test_loss: 0.1603 | test_acc: 0.9441
# [INFO] Total training time: 677.519 seconds

# %% [markdown]
# #Тесты

# %%
# Plot the loss curves of our model
plot_loss_curves(results)

# %%
from typing import List, Tuple

from PIL import Image

# 1. Take in a trained model, class names, image path, image size, a transform and target device
def pred_and_plot_image(model: torch.nn.Module,
                        image_path: str,
                        class_names: List[str],
                        image_size: Tuple[int, int] = (224, 224),
                        transform: torchvision.transforms = None,
                        device: torch.device=device):


    # 2. Open image
    img = Image.open(image_path)

    # 3. Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    ### Predict on image ###

    # 4. Make sure the model is on the target device
    model.to(device)

    # 5. Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
      # 6. Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
      transformed_image = image_transform(img).unsqueeze(dim=0)

      # 7. Make a prediction on image with an extra dimension and send it to the target device
      target_image_pred = model(transformed_image.to(device))

    # 8. Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # 9. Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    # 10. Plot image with predicted label and probability
    plt.figure()
    plt.imshow(img)
    plt.title(f"Pred: {class_names[target_image_pred_label]} | Prob: {target_image_pred_probs.max():.3f}")
    plt.axis(False);

# %%
# Get a random list of image paths from test set
import random
num_images_to_plot = 5
valid_dir = image_path / "valid"
test_image_path_list = list(Path(test_dir).glob("*/*.jpg")) # get list all image paths from test data
test_image_path_sample = random.sample(population=test_image_path_list, # go through all of the test image paths
                                       k=num_images_to_plot) # randomly select 'k' image paths to pred and plot

# Make predictions on and plot the images
for image_path in test_image_path_sample:
    pred_and_plot_image(model=model,
                        image_path=image_path,
                        class_names=class_names,
                        # transform=weights.transforms(), # optionally pass in a specified transform from our pretrained model weights
                        image_size=(224, 224))

# %%
# Download custom image
import requests

# Setup custom image path
custom_image_path = "data/sports-classification/valid/air hockey/1.jpg"


# Predict on custom image
pred_and_plot_image(model=model,
                    image_path=custom_image_path,
                    class_names=class_names)
